# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = { 
        "role": "user", 
        "content": text 
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { 
        "role": "assistant", 
        "content": text 
    }
    messages.append(assistant_message)

# %%
def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "¿Qué es la computación cuántica? Responda en una frase.")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Escriba otra frase")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
final_answer
# Out:
# 'A diferencia de los ordenadores clásicos, que utilizan bits con valores de 0 o 1, los ordenadores cuánticos emplean **cúbits** (qubits), que pueden existir en múltiples estados simultáneamente, lo que les permite explorar muchas soluciones a la vez.'
