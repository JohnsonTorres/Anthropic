# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.166666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nimport sys\n\ndef extract_s3_buckets_from_cfn(template_str):\n    \"\"\"Extract S3 bucket names from CloudFormation template\"\"\"\n    \n    try:\n        template = json.loads(template_str)\n    except json.JSONDecodeError:\n        template = {}\n    \n    buckets = set()\n    \n    # Search for S3 bucket resources\n    resources = template.get('Resources', {})\n    for resource_name, resource_config in resources.items():\n        if isinstance(resource_config, dict):\n            resource_type = resource_config.get('Type', '')\n            if resource_type == 'AWS::S3::Bucket':\n                properties = resource_config.get('Properties', {})\n                if isinstance(properties, dict) and 'BucketName' in properties:\n                    bucket_name = properties['BucketName']\n                    if isinstance(bucket_name, str):\n                        buckets.add(bucket_name)\n    \n    # Search for S3 references in all string values\n    def find_s3_refs(obj):\n        if isinstance(obj, dict):\n            for value in obj.values():\n                find_s3_refs(value)\n        elif isinstance(obj, list):\n            for item in obj:\n                find_s3_refs(item)\n        elif isinstance(obj, str):\n            # Match S3 bucket names in various formats\n            s3_patterns = [\n                r'arn:aws:s3:::([a-z0-9\\-\\.]+)(?:/|$)',\n                r's3://([a-z0-9\\-\\.]+)(?:/|$)',\n            ]\n            for pattern in s3_patterns:\n                matches = re.findall(pattern, obj)\n                for match in matches:\n                    buckets.add(match)\n    \n    find_s3_refs(template)\n    \n    return sorted(list(buckets))\n\nif __name__ == '__main__':\n    template_input = sys.stdin.read()\n    result = extract_s3_buckets_from_cfn(template_input)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Extract all S3 bucket names from an AWS CloudFormation template",
#       "format": "regex",
#       "solution_criteria": "Regex should correctly match S3 bucket name patterns (lowercase alphanumeric, hyphens, dots) and capture bucket names from CloudFormation resource definitions. Should handle quoted values and various formatting."
#     },
#     "score": 3.0,
#     "reasoning": "The solution demonstrates a solid understanding of the problem with a two-pronged approach: extracting explicit bucket name properties and searching for S3 references via regex. The recursive traversal is effective for nested structures. However, the implementation has practical limitations: it won't capture bucket names created through CloudFormation functions (very common in real templates), and the regex is overly restrictive regarding case sensitivity. The lack of validation means potentially invalid bucket names could be returned. For typical simple templates, this would work, but for production templates with dynamic resource generation, significant bucket names would be missed."
#   },
#   {
#     "output": "\nimport json\nimport re\n\ndef parse_iam_policy(policy_document):\n    \"\"\"\n    Parse an AWS IAM policy document and return a list of all allowed actions.\n    \n    Args:\n        policy_document: Either a JSON string or a Python dict representing the policy\n    \n    Returns:\n        A list of all allowed actions\n    \"\"\"\n    if isinstance(policy_document, str):\n        policy = json.loads(policy_document)\n    else:\n        policy = policy_document\n    \n    allowed_actions = []\n    \n    if \"Statement\" in policy:\n        for statement in policy[\"Statement\"]:\n            if statement.get(\"Effect\") == \"Allow\":\n                actions = statement.get(\"Action\", [])\n                \n                if isinstance(actions, str):\n                    allowed_actions.append(actions)\n                elif isinstance(actions, list):\n                    allowed_actions.extend(actions)\n    \n    return allowed_actions\n",
#     "test_case": {
#       "task": "Parse an AWS IAM policy document and return a list of all allowed actions",
#       "format": "python",
#       "solution_criteria": "Function should parse a JSON IAM policy, extract all actions from Statement blocks with Effect=Allow, and return a deduplicated list. Should handle wildcards and multiple statement formats."
#     },
#     "score": 7.5,
#     "reasoning": "The solution implements basic IAM policy parsing correctly for the core requirement of extracting Allow actions from Statement blocks. However, it fails to meet two explicit criteria: deduplication and wildcard/format handling. The code lacks robustness for complex policy structures and doesn't normalize action patterns. While functional for simple policies, it would produce incorrect results for real-world AWS policies with repeated actions or wildcard patterns that need interpretation."
#   },
#   {
#     "output": "\n{\n  \"Variables\": {\n    \"ENVIRONMENT\": \"production\",\n    \"LOG_LEVEL\": \"INFO\",\n    \"DATABASE_HOST\": \"db.example.com\",\n    \"DATABASE_PORT\": \"5432\",\n    \"DATABASE_NAME\": \"myapp_db\",\n    \"API_KEY\": \"sk-1234567890abcdef\",\n    \"TIMEOUT_SECONDS\": \"30\",\n    \"RETRY_ATTEMPTS\": \"3\",\n    \"ENABLE_CACHE\": \"true\",\n    \"S3_BUCKET\": \"my-app-bucket\",\n    \"SNS_TOPIC_ARN\": \"arn:aws:sns:us-east-1:123456789012:my-topic\",\n    \"DYNAMODB_TABLE\": \"users\",\n    \"CORS_ORIGIN\": \"https://example.com\",\n    \"FEATURE_FLAG_ANALYTICS\": \"true\",\n    \"REGION\": \"us-east-1\"\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON structure for an AWS Lambda environment variables configuration",
#       "format": "json",
#       "solution_criteria": "JSON should define environment variables for a Lambda function with proper AWS formatting, including database connection strings, API endpoints, and feature flags. Must be valid JSON that could be used in a CloudFormation template or Lambda configuration."
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates proper JSON structure and AWS formatting conventions suitable for Lambda configuration. It includes appropriate variable types and AWS resource references (ARNs). However, it has a significant security vulnerability by hardcoding sensitive credentials in plain text. Best practices would require using AWS Secrets Manager or Systems Manager Parameter Store for API keys and database credentials. The structure is functional but needs security improvements and better organization of database connection parameters."
#   }
# ]
